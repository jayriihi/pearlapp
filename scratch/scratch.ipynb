# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from modules import wind_data_functionsc

# %%
wind_data_functionsc.pearl_1hr_quik()
# Out:
# 13.0
# (13.0,
#  15,
#  13,
#  164.0,
#  ['07:17',
#   '07:22',
#   '07:27',
#   '07:32',
#   '07:37',
#   '07:42',
#   '07:47',
#   '07:52',
#   '07:57',
#   '08:02',
#   '08:07',
#   '08:12'],
#  [13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13])
